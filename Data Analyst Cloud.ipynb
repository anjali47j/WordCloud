# %% [markdown]
# # Intractive Word Cloud using Python

# %% [markdown]
# In this project, I explore how to generate a word cloud in python in any shape.
#
# So, Let's code

# %%
# WordCloud is a module of python that use to display a set of words in the form of a cloud
import wordcloud # install wordcloud by write :- python -m pip install wordcloud -:  on command prompt of jupyter notebook. 
from wordcloud import WordCloud

# %%
# WordCloud packages has its own stopwords function. stopwords contain a list that don't want to see in cloud.
from wordcloud import STOPWORDS

# %%
from PIL import Image # install PIL(python imaging library) from command prompt by using python -m PIL install Image

import numpy as np

import urllib  # urllib is a Python module that can be used for opening URLs 

import requests # Requests is a Python module that  use to send all kinds of HTTP requests 

import matplotlib.pyplot as plt

# %%
words='data analysis Data analysis Data analysis is a process of inspecting, cleansing, transforming, and modeling data with the goal of discovering useful information, informing conclusions,ll ll  l ll lll llll and supporting b bb bb decision-making. Data analysis has multiple facets and approaches, encompassing diverse techniques under a variety of names, and is used in different business, science, and social science domains. In todays business world, data analysis plays a role in making decisions more scientific and helping businesses operate more effectively Data mining  a particular data analysis technique that focuses on modeling and knowledge discovery for predictive rather than purely descriptive purposes, while business intelligence covers data analysis that relies heavily on aggregation, focusing mainly on business information.[2] In statistical applications, data analysis can be divided into descriptive statistics, exploratory data analysis (EDA), and confirmatory data analysis (CDA). EDA focuses on discovering new features in the data while CDA focuses on confirming or falsifying existing hypotheses. Predictive analytics focuses application statistical models predictive forecasting classification analytics applies statistical, linguistic structural techniques extract classify information from textual sources species unstructured data above varieties of data analysis. Data integration precursor data analysis according to whom?] and data analysis is closely linked data visualization data dissemination The term data analysis is sometimes used as a synonym for data modeling.'
mask = np.array(Image.open(requests.get('https://wpclipart.com/fictional_characters/books/Sherlock_Holmes/Holmes_silhouette.png', stream=True).raw))

# %%
# This function takes in your text and your mask and generates a wordcloud. 
def generate_wordcloud(words, mask):
    word_cloud = WordCloud(width = 512, height = 512, background_color='black', stopwords=STOPWORDS, mask=mask).generate(words)
    plt.figure(figsize=(15,10),facecolor = 'white', edgecolor='blue')
    plt.imshow(word_cloud)
    plt.axis('off')
    plt.tight_layout(pad=0)
    plt.show()
    
#Run the following to generate your wordcloud
generate_wordcloud(words, mask)

# %% [markdown]
# # There is one more word cloud of different shape

# %%
word = 'access guest guest apartment area area bathroom bed bed bed bed bed bedroom block coffee coffee coffee coffee entrance entry francisco free garden guest home house kettle kettle kitchen kitchen kitchen kitchen kitchen kitchenliving located microwave neighborhood new park parking place privacy private queen room san separate seperate shared space space space street suite time welcome'
masks = np.array(Image.open(requests.get('http://www.clker.com/cliparts/O/i/x/Y/q/P/yellow-house-hi.png', stream=True).raw))

# %%
# This function takes in your text and your mask and generates a wordcloud. 
def generate_wordcloud(word, masks):
    word_cloud = WordCloud(width = 512, height = 512, background_color='white', stopwords=STOPWORDS, mask=masks).generate(word)
    plt.figure(figsize=(10,8),facecolor = 'white', edgecolor='blue')
    plt.imshow(word_cloud)
    plt.axis('off')
    plt.tight_layout(pad=0)
    plt.show()
    
#Run the following to generate your wordcloud
generate_wordcloud(word, masks)
